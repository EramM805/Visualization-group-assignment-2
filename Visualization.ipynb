# %%
import sys
# !{sys.executable} -m pip install pandas
import pandas as pd
# Out:
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/2.2.9_1/libexec/bin/python -m pip install --upgrade pip' command.

# %%
url = "https://raw.githubusercontent.com/EramM805/Visualization-group-assignment/main/assignment-1/data/Unemployment-2016-2021.csv"
# load dataset into Pandas DataFrame
df = pd.read_csv(url)
df.columns
# Out:
# Index(['Unnamed: 0', 'index', 'FIPS Code', 'State', 'Year', 'Month',
#        'Civilian Non-Institutional Population', 'Labor Force Total',
#        'Labor Force Percent of Population', 'Employment Total',
#        'Employment Percent of Population', 'Unemployment Total',
#        'Unemployment Rate'],
#       dtype='object')

# %%
df = df.drop(["Unnamed: 0", 'index'], axis=1)

# %%
df
# Out:
#      FIPS Code          State  Year  Month  \
# 0            1        Alabama  2016      1
# 1            2         Alaska  2016      1
# 2            4        Arizona  2016      1
# 3            5       Arkansas  2016      1
# 4            6     California  2016      1
# ..         ...            ...   ...    ...
# 313         51       Virginia  2021      1
# 314         53     Washington  2021      1
# 315         54  West Virginia  2021      1
# 316         55      Wisconsin  2021      1
# 317         56        Wyoming  2021      1
#
#     Civilian Non-Institutional Population Labor Force Total  \
# 0                               3,808,871         2,138,981
# 1                                 545,180           361,853
# 2                               5,334,647         3,220,542
# 3                               2,306,098         1,344,484
# 4                              30,446,733        18,917,326
# ..                                    ...               ...
# ...

# %%
# !{sys.executable} -m pip install sklearn
from sklearn.decomposition import PCA
# Out:
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/2.2.9_1/libexec/bin/python -m pip install --upgrade pip' command.

# %%
features = ['Labor Force Total', 'Unemployment Total', 'Employment Total']

# df['Labor Force Total'] = df['Labor Force Total'].apply(lambda x: float(x.split()[0].replace(',', '')))
# df['Labor Force Total'] = df['Labor Force Total'].astype(float)
# df['Unemployment Total'] = df['Unemployment Total'].apply(lambda x: float(x.split()[0].replace(',', '')))
# df['Unemployment Total'] = df['Unemployment Total'].astype(float)
# df['Employment Total'] = df['Employment Total'].apply(lambda x: float(x.split()[0].replace(',', '')))
# df['Employment Total'] = df['Employment Total'].astype(float)
# x = df.loc[:, features].values
# x = StandardScaler().fit_transform(x)
# x
df.dtypes
x = df.loc[:, features].values
x = StandardScaler().fit_transform(x)
x
# Out:
# array([[-3.08443689e-01, -1.05791065e-01, -3.18809140e-01],
#        [-8.22772270e-01, -6.68617313e-01, -8.28135515e-01],
#        [ 4.57694584e-03,  1.77807818e-01, -5.43366697e-03],
#        [-5.38383521e-01, -4.93756620e-01, -5.38649087e-01],
#        [ 4.54747123e+00,  4.88650815e+00,  4.50842066e+00],
#        [ 5.12301931e-01,  6.89264772e-01,  4.99899260e-01],
#        [-9.90020062e-02, -2.90182406e-01, -8.75513270e-02],
#        [-3.81686386e-01, -2.68879848e-01, -3.86555996e-01],
#        [-7.91862393e-01, -6.79876481e-01, -7.94926087e-01],
#        [-8.13856822e-01, -6.59033805e-01, -8.19296821e-01],
#        [ 1.89341145e+00,  1.82399861e+00,  1.88929698e+00],
#        [ 4.47894513e-01,  6.39750863e-01,  4.34909008e-01],
#        [-7.31940049e-01, -6.83201371e-01, -7.31612906e-01],
#        [-6.94425419e-01, -6.30579297e-01, -6.95130429e-01],
#        [ 9.76656540e-01,  1.36196041e+00,  9.50247048e-01],
#        [ 3.46336250e-02,  2.11098013e-02,  3.52651155e-02],
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)

# %%
principalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])

# %%
principalDf
# Out:
#      principal component 1  principal component 2
# 0                -0.425300               0.164585
# 1                -1.340668               0.111454
# 2                 0.100346               0.146959
# 3                -0.907280               0.025250
# 4                 8.045392               0.393676
# ..                     ...                    ...
# 313               0.581673               0.097140
# 314               0.440588               0.202877
# 315              -1.110580               0.134436
# 316              -0.143976              -0.111838
# 317              -1.386880               0.090673
#
# [318 rows x 2 columns]

# %%
# !{sys.executable} -m pip install plotly
import plotly.express as px
components = pca.fit_transform(df[features])
labels = {
    str(i): f"PC {i+1} ({var:.1f}%)"
    for i, var in enumerate(pca.explained_variance_ratio_ * 100)
}

fig = px.scatter_matrix(
    components,
    labels=labels,
    dimensions=range(2),
    color=df["State"]
)
fig.update_traces(diagonal_visible=False)
fig.show()
# Out:
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/2.2.9_1/libexec/bin/python -m pip install --upgrade pip' command.
# ...

# %%
df
# Out:
#      FIPS Code          State  Year  Month  \
# 0            1        Alabama  2016      1
# 1            2         Alaska  2016      1
# 2            4        Arizona  2016      1
# 3            5       Arkansas  2016      1
# 4            6     California  2016      1
# ..         ...            ...   ...    ...
# 313         51       Virginia  2021      1
# 314         53     Washington  2021      1
# 315         54  West Virginia  2021      1
# 316         55      Wisconsin  2021      1
# 317         56        Wyoming  2021      1
#
#     Civilian Non-Institutional Population  Labor Force Total  \
# 0                               3,808,871          2138981.0
# 1                                 545,180           361853.0
# 2                               5,334,647          3220542.0
# 3                               2,306,098          1344484.0
# 4                              30,446,733         18917326.0
# ..                                    ...                ...
# ...

# %%
components
# Out:
# array([[-1.49263182e+06,  4.27109185e+04],
#        [-3.93397983e+06,  2.21633769e+04],
#        [ 4.35281689e+02,  4.12195764e+04],
#        [-2.56728187e+06,  1.14552948e+03],
#        [ 2.15964038e+07,  1.60356457e+05],
#        [ 2.41587690e+06,  5.10201284e+04],
#        [-4.47525365e+05, -4.71401149e+04],
#        [-1.83007202e+06,  2.00881449e+04],
#        [-3.78170626e+06,  1.26916808e+04],
#        [-3.89163987e+06,  2.24785603e+04],
#        [ 9.01794801e+06,  1.67588781e+04],
#        [ 2.10757292e+06,  5.34262491e+04],
#        [-3.48878606e+06, -1.27632614e+03],
#        [-3.31214200e+06,  2.97007549e+03],
#        [ 4.59974067e+06,  1.08650188e+05],
#        [ 1.66462964e+05, -2.60359229e+03],
#        [-2.05640008e+06, -1.48510981e+04],
#        [-2.35232848e+06, -5.26532626e+03],
#        [-1.67649120e+06,  1.92081192e+04],
#        [-1.49825218e+06,  4.17786018e+04],
#        [-3.47603921e+06,  6.61851272e+03],
#        [-7.77678066e+04, -6.77436763e+03],
# ...

# %%
features
# Out:
# ['Labor Force Total', 'Unemployment Total', 'Employment Total']
